# %%
import pandas as pd

ratings = pd.read_csv('.\\data\\rating.csv', sep=',', encoding="ISO-8859-1")
animes = pd.read_csv('.\\data\\anime.csv', sep=',', encoding="ISO-8859-1")

ratings = ratings[ratings['rating'] != -1]

ratings = ratings[ratings.groupby('user_id')['user_id'].transform('count') >= 100]

ratings = pd.merge(ratings, animes[['anime_id', 'name']], on='anime_id', how='left')

print(ratings)
# Out:
#        user_id  anime_id  rating  \
# 0            5         6       8
# 1            5        15       6
# 2            5        17       6
# 3            5        18       6
# 4            5        20       6
# ...        ...       ...     ...
# 57656     1026     14741      10
# 57657     1026     16353       9
# 57658     1026     16742       6
# 57659     1026     16782      10
# 57660     1026     23289      10
#
#                                                     name
# 0                                                 Trigun
# 1                                           Eyeshield 21
# 2                             Hungry Heart: Wild Striker
# 3                                 Initial D Fourth Stage
# 4                                                 Naruto
# ...                                                  ...
# 57656                     Chuunibyou demo Koi ga Shitai!
# 57657                                           Love Lab
# 57658  Watashi ga Motenai no wa Dou Kangaetemo Omaera...
# 57659                                   Kotonoha no Niwa
# 57660                           Gekkan Shoujo Nozaki-kun
#
# [57661 rows x 4 columns]

# %%
userRatings = ratings.pivot_table(index=['user_id'],columns=['name'],values='rating')
userRatings.head()
# Out:
# name     &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hatsukoi  \
# user_id
# 5                                                      NaN
# 7                                                      NaN
# 11                                                     NaN
# 14                                                     NaN
# 17                                                     NaN
#
# name     &quot;Bungaku Shoujo&quot; Memoire  &quot;Bungaku Shoujo&quot; Movie  \
# user_id
# 5                                       NaN                               NaN
# 7                                       NaN                               NaN
# 11                                      NaN                               NaN
# 14                                      NaN                               8.0
# 17                                      NaN                               NaN
#
# name     .hack//G.U. Returner  .hack//G.U. Trilogy  .hack//Gift  \
# user_id
# 5                         NaN                  NaN          NaN
# 7                         NaN                  NaN          NaN
# 11                        NaN                  NaN          NaN
# 14                        NaN                  NaN          NaN
# 17                        NaN                  NaN          NaN
#
# name     .hack//Intermezzo  .hack//Liminality  .hack//Quantum  .hack//Roots  \
# user_id
# 5                      NaN                NaN             NaN           NaN
# 7                      NaN                NaN             NaN           NaN
# 11                     NaN                NaN             NaN           NaN
# 14                     NaN                NaN             NaN           NaN
# 17                     NaN                NaN             NaN           NaN
#
# name     ...  ef: A Tale of Memories. - Recollections  gdgd Fairies  \
# user_id  ...
# 5        ...                                      NaN           NaN
# 7        ...                                      NaN           NaN
# 11       ...                                      NaN           NaN
# 14       ...                                      NaN           NaN
# 17       ...                                      NaN           6.0
#
# name     gdgd Fairies 2  iDOLM@STER Xenoglossia  s.CRY.ed  xxxHOLiC  \
# user_id
# 5                   NaN                     NaN       NaN       2.0
# 7                   NaN                     NaN       NaN       NaN
# 11                  NaN                     NaN       NaN       NaN
# 14                  NaN                     NaN       NaN       NaN
# 17                  6.0                     NaN       NaN       NaN
#
# name     xxxHOLiC Kei  xxxHOLiC Movie: Manatsu no Yoru no Yume  xxxHOLiC Rou  \
# user_id
# 5                 NaN                                      NaN           NaN
# 7                 NaN                                      NaN           NaN
# 11                NaN                                      NaN           NaN
# 14                NaN                                      NaN           NaN
# 17                NaN                                      NaN           NaN
#
# name     xxxHOLiC Shunmuki
# user_id
# 5                      NaN
# 7                      NaN
# 11                     NaN
# 14                     NaN
# 17                     NaN
#
# [5 rows x 4308 columns]

# %%
corrMatrix = userRatings.corr()
corrMatrix.head()
# Out:
# name                                                &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hatsukoi  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                                           1.000000
# &quot;Bungaku Shoujo&quot; Memoire                                                           0.482805
# &quot;Bungaku Shoujo&quot; Movie                                                             0.544949
# .hack//G.U. Returner                                                                         0.755929
# .hack//G.U. Trilogy                                                                          1.000000
#
# name                                                &quot;Bungaku Shoujo&quot; Memoire  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                            0.482805
# &quot;Bungaku Shoujo&quot; Memoire                                            1.000000
# &quot;Bungaku Shoujo&quot; Movie                                              0.934199
# .hack//G.U. Returner                                                         -0.500000
# .hack//G.U. Trilogy                                                           1.000000
#
# name                                                &quot;Bungaku Shoujo&quot; Movie  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                          0.544949
# &quot;Bungaku Shoujo&quot; Memoire                                          0.934199
# &quot;Bungaku Shoujo&quot; Movie                                            1.000000
# .hack//G.U. Returner                                                        0.000000
# .hack//G.U. Trilogy                                                         0.654654
#
# name                                                .hack//G.U. Returner  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...              0.755929
# &quot;Bungaku Shoujo&quot; Memoire                             -0.500000
# &quot;Bungaku Shoujo&quot; Movie                                0.000000
# .hack//G.U. Returner                                            1.000000
# .hack//G.U. Trilogy                                             0.755929
#
# name                                                .hack//G.U. Trilogy  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...             1.000000
# &quot;Bungaku Shoujo&quot; Memoire                             1.000000
# &quot;Bungaku Shoujo&quot; Movie                               0.654654
# .hack//G.U. Returner                                           0.755929
# .hack//G.U. Trilogy                                            1.000000
#
# name                                                .hack//Gift  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...          NaN
# &quot;Bungaku Shoujo&quot; Memoire                          NaN
# &quot;Bungaku Shoujo&quot; Movie                            NaN
# .hack//G.U. Returner                                        NaN
# .hack//G.U. Trilogy                                         NaN
#
# name                                                .hack//Intermezzo  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                NaN
# &quot;Bungaku Shoujo&quot; Memoire                                NaN
# &quot;Bungaku Shoujo&quot; Movie                                  1.0
# .hack//G.U. Returner                                              1.0
# .hack//G.U. Trilogy                                               1.0
#
# name                                                .hack//Liminality  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                NaN
# &quot;Bungaku Shoujo&quot; Memoire                                NaN
# &quot;Bungaku Shoujo&quot; Movie                                  1.0
# .hack//G.U. Returner                                              1.0
# .hack//G.U. Trilogy                                               1.0
#
# name                                                .hack//Quantum  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...             NaN
# &quot;Bungaku Shoujo&quot; Memoire                             NaN
# &quot;Bungaku Shoujo&quot; Movie                          0.214809
# .hack//G.U. Returner                                      1.000000
# .hack//G.U. Trilogy                                       0.606788
#
# name                                                .hack//Roots  ...  \
# name                                                              ...
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...           NaN  ...
# &quot;Bungaku Shoujo&quot; Memoire                           NaN  ...
# &quot;Bungaku Shoujo&quot; Movie                        0.899954  ...
# .hack//G.U. Returner                                    0.944911  ...
# .hack//G.U. Trilogy                                     0.944911  ...
#
# name                                                ef: A Tale of Memories. - Recollections  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                                      NaN
# &quot;Bungaku Shoujo&quot; Memoire                                                      NaN
# &quot;Bungaku Shoujo&quot; Movie                                                        NaN
# .hack//G.U. Returner                                                                    NaN
# .hack//G.U. Trilogy                                                                     NaN
#
# name                                                gdgd Fairies  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...           NaN
# &quot;Bungaku Shoujo&quot; Memoire                           NaN
# &quot;Bungaku Shoujo&quot; Movie                             NaN
# .hack//G.U. Returner                                         NaN
# .hack//G.U. Trilogy                                          NaN
#
# name                                                gdgd Fairies 2  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...             NaN
# &quot;Bungaku Shoujo&quot; Memoire                             NaN
# &quot;Bungaku Shoujo&quot; Movie                               NaN
# .hack//G.U. Returner                                           NaN
# .hack//G.U. Trilogy                                            NaN
#
# name                                                iDOLM@STER Xenoglossia  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                     NaN
# &quot;Bungaku Shoujo&quot; Memoire                                     NaN
# &quot;Bungaku Shoujo&quot; Movie                                       NaN
# .hack//G.U. Returner                                                   NaN
# .hack//G.U. Trilogy                                                    NaN
#
# name                                                s.CRY.ed  xxxHOLiC  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...       NaN  0.577350
# &quot;Bungaku Shoujo&quot; Memoire                       NaN  0.577350
# &quot;Bungaku Shoujo&quot; Movie                         NaN  0.534522
# .hack//G.U. Returner                                     NaN       NaN
# .hack//G.U. Trilogy                                     -1.0 -0.471405
#
# name                                                xxxHOLiC Kei  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...      0.577350
# &quot;Bungaku Shoujo&quot; Memoire                      0.577350
# &quot;Bungaku Shoujo&quot; Movie                        0.870388
# .hack//G.U. Returner                                         NaN
# .hack//G.U. Trilogy                                     0.188982
#
# name                                                xxxHOLiC Movie: Manatsu no Yoru no Yume  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                                 0.866025
# &quot;Bungaku Shoujo&quot; Memoire                                                 0.866025
# &quot;Bungaku Shoujo&quot; Movie                                                   1.000000
# .hack//G.U. Returner                                                                    NaN
# .hack//G.U. Trilogy                                                                     NaN
#
# name                                                xxxHOLiC Rou  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...      0.500000
# &quot;Bungaku Shoujo&quot; Memoire                      0.500000
# &quot;Bungaku Shoujo&quot; Movie                        0.866025
# .hack//G.U. Returner                                         NaN
# .hack//G.U. Trilogy                                     1.000000
#
# name                                                xxxHOLiC Shunmuki
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                0.5
# &quot;Bungaku Shoujo&quot; Memoire                                0.5
# &quot;Bungaku Shoujo&quot; Movie                                  0.5
# .hack//G.U. Returner                                              NaN
# .hack//G.U. Trilogy                                               NaN
#
# [5 rows x 4308 columns]

# %%
corrMatrix = userRatings.corr(method='pearson', min_periods=100)
corrMatrix.head()
# Out:
# name                                                &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hatsukoi  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                                                NaN
# &quot;Bungaku Shoujo&quot; Memoire                                                                NaN
# &quot;Bungaku Shoujo&quot; Movie                                                                  NaN
# .hack//G.U. Returner                                                                              NaN
# .hack//G.U. Trilogy                                                                               NaN
#
# name                                                &quot;Bungaku Shoujo&quot; Memoire  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                                 NaN
# &quot;Bungaku Shoujo&quot; Memoire                                                 NaN
# &quot;Bungaku Shoujo&quot; Movie                                                   NaN
# .hack//G.U. Returner                                                               NaN
# .hack//G.U. Trilogy                                                                NaN
#
# name                                                &quot;Bungaku Shoujo&quot; Movie  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                               NaN
# &quot;Bungaku Shoujo&quot; Memoire                                               NaN
# &quot;Bungaku Shoujo&quot; Movie                                                 NaN
# .hack//G.U. Returner                                                             NaN
# .hack//G.U. Trilogy                                                              NaN
#
# name                                                .hack//G.U. Returner  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                   NaN
# &quot;Bungaku Shoujo&quot; Memoire                                   NaN
# &quot;Bungaku Shoujo&quot; Movie                                     NaN
# .hack//G.U. Returner                                                 NaN
# .hack//G.U. Trilogy                                                  NaN
#
# name                                                .hack//G.U. Trilogy  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                  NaN
# &quot;Bungaku Shoujo&quot; Memoire                                  NaN
# &quot;Bungaku Shoujo&quot; Movie                                    NaN
# .hack//G.U. Returner                                                NaN
# .hack//G.U. Trilogy                                                 NaN
#
# name                                                .hack//Gift  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...          NaN
# &quot;Bungaku Shoujo&quot; Memoire                          NaN
# &quot;Bungaku Shoujo&quot; Movie                            NaN
# .hack//G.U. Returner                                        NaN
# .hack//G.U. Trilogy                                         NaN
#
# name                                                .hack//Intermezzo  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                NaN
# &quot;Bungaku Shoujo&quot; Memoire                                NaN
# &quot;Bungaku Shoujo&quot; Movie                                  NaN
# .hack//G.U. Returner                                              NaN
# .hack//G.U. Trilogy                                               NaN
#
# name                                                .hack//Liminality  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                NaN
# &quot;Bungaku Shoujo&quot; Memoire                                NaN
# &quot;Bungaku Shoujo&quot; Movie                                  NaN
# .hack//G.U. Returner                                              NaN
# .hack//G.U. Trilogy                                               NaN
#
# name                                                .hack//Quantum  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...             NaN
# &quot;Bungaku Shoujo&quot; Memoire                             NaN
# &quot;Bungaku Shoujo&quot; Movie                               NaN
# .hack//G.U. Returner                                           NaN
# .hack//G.U. Trilogy                                            NaN
#
# name                                                .hack//Roots  ...  \
# name                                                              ...
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...           NaN  ...
# &quot;Bungaku Shoujo&quot; Memoire                           NaN  ...
# &quot;Bungaku Shoujo&quot; Movie                             NaN  ...
# .hack//G.U. Returner                                         NaN  ...
# .hack//G.U. Trilogy                                          NaN  ...
#
# name                                                ef: A Tale of Memories. - Recollections  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                                      NaN
# &quot;Bungaku Shoujo&quot; Memoire                                                      NaN
# &quot;Bungaku Shoujo&quot; Movie                                                        NaN
# .hack//G.U. Returner                                                                    NaN
# .hack//G.U. Trilogy                                                                     NaN
#
# name                                                gdgd Fairies  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...           NaN
# &quot;Bungaku Shoujo&quot; Memoire                           NaN
# &quot;Bungaku Shoujo&quot; Movie                             NaN
# .hack//G.U. Returner                                         NaN
# .hack//G.U. Trilogy                                          NaN
#
# name                                                gdgd Fairies 2  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...             NaN
# &quot;Bungaku Shoujo&quot; Memoire                             NaN
# &quot;Bungaku Shoujo&quot; Movie                               NaN
# .hack//G.U. Returner                                           NaN
# .hack//G.U. Trilogy                                            NaN
#
# name                                                iDOLM@STER Xenoglossia  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                     NaN
# &quot;Bungaku Shoujo&quot; Memoire                                     NaN
# &quot;Bungaku Shoujo&quot; Movie                                       NaN
# .hack//G.U. Returner                                                   NaN
# .hack//G.U. Trilogy                                                    NaN
#
# name                                                s.CRY.ed  xxxHOLiC  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...       NaN       NaN
# &quot;Bungaku Shoujo&quot; Memoire                       NaN       NaN
# &quot;Bungaku Shoujo&quot; Movie                         NaN       NaN
# .hack//G.U. Returner                                     NaN       NaN
# .hack//G.U. Trilogy                                      NaN       NaN
#
# name                                                xxxHOLiC Kei  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...           NaN
# &quot;Bungaku Shoujo&quot; Memoire                           NaN
# &quot;Bungaku Shoujo&quot; Movie                             NaN
# .hack//G.U. Returner                                         NaN
# .hack//G.U. Trilogy                                          NaN
#
# name                                                xxxHOLiC Movie: Manatsu no Yoru no Yume  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                                      NaN
# &quot;Bungaku Shoujo&quot; Memoire                                                      NaN
# &quot;Bungaku Shoujo&quot; Movie                                                        NaN
# .hack//G.U. Returner                                                                    NaN
# .hack//G.U. Trilogy                                                                     NaN
#
# name                                                xxxHOLiC Rou  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...           NaN
# &quot;Bungaku Shoujo&quot; Memoire                           NaN
# &quot;Bungaku Shoujo&quot; Movie                             NaN
# .hack//G.U. Returner                                         NaN
# .hack//G.U. Trilogy                                          NaN
#
# name                                                xxxHOLiC Shunmuki
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                NaN
# &quot;Bungaku Shoujo&quot; Memoire                                NaN
# &quot;Bungaku Shoujo&quot; Movie                                  NaN
# .hack//G.U. Returner                                              NaN
# .hack//G.U. Trilogy                                               NaN
#
# [5 rows x 4308 columns]

# %%
print(corrMatrix.shape)
myRatings = userRatings.iloc[0].dropna()
myRatings
# Out:
# (4308, 4308)
# name
# Absolute Duo                             2.0
# Accel World                              3.0
# Akame ga Kill!                           4.0
# Akira                                    8.0
# Amaama to Inazuma                        7.0
#                                         ...
# Zero no Tsukaima: Futatsuki no Kishi     1.0
# Zero no Tsukaima: Princesses no Rondo    1.0
# Zetsumetsu Kigu Shoujo: Amazing Twins    4.0
# Zoku Sayonara Zetsubou Sensei            7.0
# xxxHOLiC                                 2.0
# Name: 5, Length: 459, dtype: float64

# %%
simCandidates = pd.Series()
print(simCandidates)
for i in range(0, len(myRatings.index)):
    print ("Añadiendo pelis similares a " + myRatings.index[i] + "...")
    sims = corrMatrix[myRatings.index[i]].dropna()
    sims = sims.map(lambda x: x * myRatings[i])
    simCandidates = pd.concat([simCandidates, sims])
    
print ("Ordenando...")
simCandidates.sort_values(inplace = True, ascending = False)
print (simCandidates.head(10))
# Out:
# Series([], dtype: object)
# Añadiendo pelis similares a Absolute Duo...
# Añadiendo pelis similares a Accel World...
# Añadiendo pelis similares a Akame ga Kill!...
# Añadiendo pelis similares a Akira...
# Añadiendo pelis similares a Amaama to Inazuma...
# Añadiendo pelis similares a Amagi Brilliant Park...
# Añadiendo pelis similares a Angel Beats!...
# Añadiendo pelis similares a Angel Densetsu...
# Añadiendo pelis similares a Ano Hi Mita Hana no Namae wo Bokutachi wa Mada Shiranai....
# Añadiendo pelis similares a Ano Hi Mita Hana no Namae wo Bokutachi wa Mada Shiranai. Movie...
# Añadiendo pelis similares a Ano Natsu de Matteru...
# Añadiendo pelis similares a Ano Natsu de Matteru: Bokutachi wa Koukou Saigo no Natsu wo Sugoshinagara, Ano Natsu de Matteiru....
# Añadiendo pelis similares a Ao no Exorcist...
# Añadiendo pelis similares a Arakawa Under the Bridge...
# Añadiendo pelis similares a Arakawa Under the Bridge x Bridge...
# Añadiendo pelis similares a Asa made Jugyou Chu!...
# Añadiendo pelis similares a Asu no Yoichi!...
# Añadiendo pelis similares a Aura: Maryuuin Kouga Saigo no Tatakai...
# Añadiendo pelis similares a B Gata H Kei...
# Añadiendo pelis similares a B-Densetsu! Battle Bedaman...
# Añadiendo pelis similares a B-Densetsu! Battle Bedaman Enkon...
# Añadiendo pelis similares a Baby Steps...
# Añadiendo pelis similares a Baka to Test to Shoukanjuu...
# Añadiendo pelis similares a Baka to Test to Shoukanjuu Ni!...
# Añadiendo pelis similares a Baka to Test to Shoukanjuu: Matsuri...
# Añadiendo pelis similares a Bakuman....
# Añadiendo pelis similares a Bakuman. 2nd Season...
# Añadiendo pelis similares a Bakuten Shoot Beyblade...
# Añadiendo pelis similares a Bakuten Shoot Beyblade 2002...
# Añadiendo pelis similares a Bakuten Shoot Beyblade G Revolution...
# Añadiendo pelis similares a Barakamon...
# Añadiendo pelis similares a Basilisk: Kouga Ninpou Chou...
# Añadiendo pelis similares a Beck...
# Añadiendo pelis similares a Ben-To...
# Añadiendo pelis similares a Ben-To Picture Drama...
# Añadiendo pelis similares a Binbougami ga!...
# Añadiendo pelis similares a Black Bullet...
# Añadiendo pelis similares a Black Cat...
# Añadiendo pelis similares a Bleach...
# Añadiendo pelis similares a Blood Lad...
# Añadiendo pelis similares a Blood Lad: Wagahai wa Neko de wa Nai...
# Añadiendo pelis similares a Blood+...
# Añadiendo pelis similares a Boku wa Tomodachi ga Sukunai...
# Añadiendo pelis similares a Boku wa Tomodachi ga Sukunai Episode 0...
# Añadiendo pelis similares a Boku wa Tomodachi ga Sukunai Next...
# Añadiendo pelis similares a Boku wa Tomodachi ga Sukunai: Relay Shousetsu wa Ketsumatsu ga Hanpanai...
# Añadiendo pelis similares a Bokura wa Minna Kawaisou...
# Añadiendo pelis similares a Bokura wa Minna Kawaisou: Hajimete no...
# Añadiendo pelis similares a Buzzer Beater...
# Añadiendo pelis similares a Buzzer Beater 2nd Season...
# Añadiendo pelis similares a Byousoku 5 Centimeter...
# Añadiendo pelis similares a C: The Money of Soul and Possibility Control...
# Añadiendo pelis similares a Captain Tsubasa...
# Añadiendo pelis similares a Captain Tsubasa J...
# Añadiendo pelis similares a Captain Tsubasa: Road to 2002...
# Añadiendo pelis similares a Cardcaptor Sakura...
# Añadiendo pelis similares a Cardcaptor Sakura Movie 1...
# Añadiendo pelis similares a Cardcaptor Sakura Specials...
# Añadiendo pelis similares a Chuunibyou demo Koi ga Shitai!...
# Añadiendo pelis similares a Chuunibyou demo Koi ga Shitai! Ren...
# Añadiendo pelis similares a ChÃ¤oS;HEAd...
# Añadiendo pelis similares a Coppelion...
# Añadiendo pelis similares a Cyborg Kuro-chan...
# Añadiendo pelis similares a D-Frag!...
# Añadiendo pelis similares a Daitoshokan no Hitsujikai...
# Añadiendo pelis similares a Dakara Boku wa, H ga Dekinai....
# Añadiendo pelis similares a Danganronpa: Kibou no Gakuen to Zetsubou no Koukousei The Animation...
# Añadiendo pelis similares a Danna ga Nani wo Itteiru ka Wakaranai Ken...
# Añadiendo pelis similares a Danshi Koukousei no Nichijou...
# Añadiendo pelis similares a Date A Live...
# Añadiendo pelis similares a Date A Live II...
# Añadiendo pelis similares a Date A Live: Date to Date...
# Añadiendo pelis similares a Dear Boys...
# Añadiendo pelis similares a DearS...
# Añadiendo pelis similares a Death Note...
# Añadiendo pelis similares a Denpa Onna to Seishun Otoko...
# Añadiendo pelis similares a Denpa Onna to Seishun Otoko Special...
# Añadiendo pelis similares a Detroit Metal City...
# Añadiendo pelis similares a Diamond no Ace...
# Añadiendo pelis similares a Digimon Adventure...
# Añadiendo pelis similares a Digimon Adventure 02...
# Añadiendo pelis similares a Digimon Adventure 02 Movies...
# Añadiendo pelis similares a Digimon Adventure 02: Diablomon no Gyakushuu...
# Añadiendo pelis similares a Digimon Adventure Movie...
# Añadiendo pelis similares a Digimon Adventure: Bokura no War Game!...
# Añadiendo pelis similares a Digimon Frontier...
# Añadiendo pelis similares a Digimon Tamers...
# Añadiendo pelis similares a Dragon Ball...
# Añadiendo pelis similares a Dragon Ball GT...
# Añadiendo pelis similares a Dragon Ball GT: Goku Gaiden! Yuuki no Akashi wa Suushinchuu...
# Añadiendo pelis similares a Dragon Ball Z...
# Añadiendo pelis similares a Dragon Ball Z Movie 03: Chikyuu Marugoto Choukessen...
# Añadiendo pelis similares a Dragon Ball Z Movie 05: Tobikkiri no Saikyou tai Saikyou...
# Añadiendo pelis similares a Dragon Ball Z Movie 10: Kiken na Futari! Super Senshi wa Nemurenai...
# Añadiendo pelis similares a Dragon Ball Z Movie 12: Fukkatsu no Fusion!! Gokuu to Vegeta...
# Añadiendo pelis similares a Dungeon ni Deai wo Motomeru no wa Machigatteiru Darou ka...
# Añadiendo pelis similares a Durarara!!...
# Añadiendo pelis similares a Durarara!! Specials...
# Añadiendo pelis similares a Durarara!!x2 Shou...
# Añadiendo pelis similares a Eyeshield 21...
# Añadiendo pelis similares a Fairy Tail...
# Añadiendo pelis similares a Freezing...
# Añadiendo pelis similares a Freezing Specials...
# Añadiendo pelis similares a Freezing Vibration...
# Añadiendo pelis similares a Futatsu no Spica...
# Añadiendo pelis similares a Gangsta....
# Añadiendo pelis similares a Gatchaman Crowds...
# Añadiendo pelis similares a Gate: Jieitai Kanochi nite, Kaku Tatakaeri...
# Añadiendo pelis similares a Gekkan Shoujo Nozaki-kun...
# Añadiendo pelis similares a Genshiken...
# Añadiendo pelis similares a Genshiken 2...
# Añadiendo pelis similares a Genshiken Nidaime...
# Añadiendo pelis similares a GetBackers...
# Añadiendo pelis similares a Ghost Sweeper GS Mikami...
# Añadiendo pelis similares a Giant Killing...
# Añadiendo pelis similares a Gin no Saji...
# Añadiendo pelis similares a Gin no Saji 2nd Season...
# Añadiendo pelis similares a Gintama...
# Añadiendo pelis similares a Gintama Movie: Kanketsu-hen - Yorozuya yo Eien Nare...
# Añadiendo pelis similares a Gintama&#039;...
# Añadiendo pelis similares a Gintama&#039;: Enchousen...
# Añadiendo pelis similares a Girls Bravo: First Season...
# Añadiendo pelis similares a Girls Bravo: Second Season...
# Añadiendo pelis similares a Glasslip...
# Añadiendo pelis similares a Gokukoku no Brynhildr...
# Añadiendo pelis similares a Golden Boy...
# Añadiendo pelis similares a Golden Time...
# Añadiendo pelis similares a Great Teacher Onizuka...
# Añadiendo pelis similares a Grisaia no Kajitsu...
# Añadiendo pelis similares a Gugure! Kokkuri-san...
# Añadiendo pelis similares a Hagure Yuusha no Aesthetica...
# Añadiendo pelis similares a Hagure Yuusha no Aesthetica: Hajirai Ippai...
# Añadiendo pelis similares a Haikyuu!!...
# Añadiendo pelis similares a Haikyuu!! Second Season...
# Añadiendo pelis similares a Haiyore! Nyaruko-san...
# Añadiendo pelis similares a Hajime no Ippo...
# Añadiendo pelis similares a Hajime no Ippo: Boxer no Kobushi...
# Añadiendo pelis similares a Hajime no Ippo: Champion Road...
# Añadiendo pelis similares a Hajime no Ippo: Mashiba vs. Kimura...
# Añadiendo pelis similares a Hajime no Ippo: New Challenger...
# Añadiendo pelis similares a Hajime no Ippo: Rising...
# Añadiendo pelis similares a Hamatora The Animation...
# Añadiendo pelis similares a Hataraku Maou-sama!...
# Añadiendo pelis similares a Hentai Ouji to Warawanai Neko....
# Añadiendo pelis similares a Heppoko Jikken Animation Excelâ¥Saga...
# Añadiendo pelis similares a High School DxD...
# Añadiendo pelis similares a High School DxD New...
# Añadiendo pelis similares a High School DxD OVA...
# Añadiendo pelis similares a High School DxD Specials...
# Añadiendo pelis similares a Highschool of the Dead...
# Añadiendo pelis similares a Hitsugi no Chaika...
# Añadiendo pelis similares a Hoozuki no Reitetsu...
# Añadiendo pelis similares a Hungry Heart: Wild Striker...
# Añadiendo pelis similares a Hunter x Hunter...
# Añadiendo pelis similares a Hunter x Hunter OVA...
# Añadiendo pelis similares a Hunter x Hunter: Greed Island...
# Añadiendo pelis similares a Hunter x Hunter: Greed Island Final...
# Añadiendo pelis similares a Hyakka Ryouran: Samurai Girls...
# Añadiendo pelis similares a Hyouka...
# Añadiendo pelis similares a IS: Infinite Stratos...
# Añadiendo pelis similares a IS: Infinite Stratos 2...
# Añadiendo pelis similares a IS: Infinite Stratos 2 - Hitonatsu no Omoide...
# Añadiendo pelis similares a Ichiban Ushiro no Daimaou...
# Añadiendo pelis similares a Ichigo 100%...
# Añadiendo pelis similares a Ichigo 100% OVA...
# Añadiendo pelis similares a Ike! Ina-chuu Takkyuubu...
# Añadiendo pelis similares a Ikkitousen: Dragon Destiny...
# Añadiendo pelis similares a Imawa no Kuni no Alice (OVA)...
# Añadiendo pelis similares a Inari, Konkon, Koi Iroha....
# Añadiendo pelis similares a Initial D Fifth Stage...
# Añadiendo pelis similares a Initial D First Stage...
# Añadiendo pelis similares a Initial D Fourth Stage...
# Añadiendo pelis similares a Initial D Second Stage...
# Añadiendo pelis similares a Inou-Battle wa Nichijou-kei no Naka de...
# Añadiendo pelis similares a Inu x Boku SS...
# Añadiendo pelis similares a Inu x Boku SS Special...
# Añadiendo pelis similares a InuYasha...
# Añadiendo pelis similares a Isshuukan Friends....
# Añadiendo pelis similares a Isuca...
# Añadiendo pelis similares a Jibaku-kun...
# Añadiendo pelis similares a Jitsu wa Watashi wa...
# Añadiendo pelis similares a JoJo no Kimyou na Bouken (TV)...
# Añadiendo pelis similares a JoJo no Kimyou na Bouken: Stardust Crusaders...
# Añadiendo pelis similares a JoJo no Kimyou na Bouken: Stardust Crusaders 2nd Season...
# Añadiendo pelis similares a Junketsu no Maria...
# Añadiendo pelis similares a Juuou Mujin no Fafnir...
# Añadiendo pelis similares a K...
# Añadiendo pelis similares a K-On!...
# Añadiendo pelis similares a K-On!!...
# Añadiendo pelis similares a Kami nomi zo Shiru Sekai...
# Añadiendo pelis similares a Kami nomi zo Shiru Sekai II...
# Añadiendo pelis similares a Kami nomi zo Shiru Sekai: 4-nin to Idol...
# Añadiendo pelis similares a Kami nomi zo Shiru Sekai: Megami-hen...
# Añadiendo pelis similares a Kanokon...
# Añadiendo pelis similares a Kanokon Specials...
# Añadiendo pelis similares a Kanokon: Manatsu no Dai Shanikusai...
# Añadiendo pelis similares a Kimi no Iru Machi...
# Añadiendo pelis similares a Kiseijuu: Sei no Kakuritsu...
# Añadiendo pelis similares a Kiss x Sis...
# Añadiendo pelis similares a Kiss x Sis (TV)...
# Añadiendo pelis similares a Konjiki no Gash Bell!!...
# Añadiendo pelis similares a Kono Naka ni Hitori, Imouto ga Iru!...
# Añadiendo pelis similares a Kono Naka ni Hitori, Imouto ga Iru!: Ani, Imouto, Koibito...
# Añadiendo pelis similares a Kono Subarashii Sekai ni Shukufuku wo!...
# Añadiendo pelis similares a Kore wa Zombie Desu ka?...
# Añadiendo pelis similares a Kore wa Zombie Desu ka? OVA...
# Añadiendo pelis similares a Kore wa Zombie Desu ka? of the Dead...
# Añadiendo pelis similares a Kore wa Zombie Desu ka? of the Dead OVA...
# Añadiendo pelis similares a Kotonoha no Niwa...
# Añadiendo pelis similares a Kotoura-san...
# Añadiendo pelis similares a Kotoura-san: Haruka no Heya...
# Añadiendo pelis similares a Kuroko no Basket 2nd Season...
# Añadiendo pelis similares a Kyoukai no Kanata...
# Añadiendo pelis similares a Ladies versus Butlers!...
# Añadiendo pelis similares a Ladies versus Butlers! Specials...
# Añadiendo pelis similares a Ladies versus Butlers! Tokuten Disc Music Clip...
# Añadiendo pelis similares a Little Witch Academia...
# Añadiendo pelis similares a Log Horizon...
# Añadiendo pelis similares a Love Hina...
# Añadiendo pelis similares a Love Hina Again...
# Añadiendo pelis similares a Love Lab...
# Añadiendo pelis similares a LovelyâComplex...
# Añadiendo pelis similares a LuckyâStar...
# Añadiendo pelis similares a LuckyâStar: Original na Visual to Animation...
# Añadiendo pelis similares a MM!...
# Añadiendo pelis similares a Machine-Doll wa Kizutsukanai...
# Añadiendo pelis similares a Magi: The Kingdom of Magic...
# Añadiendo pelis similares a Magi: The Labyrinth of Magic...
# Añadiendo pelis similares a Mahou Sensou...
# Añadiendo pelis similares a Mahouka Koukou no Rettousei...
# Añadiendo pelis similares a Maken-Ki!...
# Añadiendo pelis similares a Maken-Ki! Two...
# Añadiendo pelis similares a Mangaka-san to Assistant-san to The Animation...
# Añadiendo pelis similares a Mangchi...
# Añadiendo pelis similares a Mashiro-iro Symphony: The Color of Lovers...
# Añadiendo pelis similares a Matantei Loki Ragnarok...
# Añadiendo pelis similares a Mayo Chiki!...
# Añadiendo pelis similares a Medaka Box...
# Añadiendo pelis similares a Medaka Box Abnormal...
# Añadiendo pelis similares a Medarot...
# Añadiendo pelis similares a Medarot Damashii...
# Añadiendo pelis similares a Mekakucity Actors...
# Añadiendo pelis similares a Mikakunin de Shinkoukei...
# Añadiendo pelis similares a Mob Psycho 100...
# Añadiendo pelis similares a Mondaiji-tachi ga Isekai kara Kuru Sou Desu yo?...
# Añadiendo pelis similares a Mondaiji-tachi ga Isekai kara Kuru Sou Desu yo?: Onsen Manyuuki...
# Añadiendo pelis similares a Monster Farm: Enbanseki no Himitsu...
# Añadiendo pelis similares a Monster Farm: Legend e no Michi...
# Añadiendo pelis similares a Motto To LOVE-Ru...
# Añadiendo pelis similares a Mou Hitotsu no Mirai wo....
# Añadiendo pelis similares a Mujin Wakusei Survive...
# Añadiendo pelis similares a Mushibugyou...
# Añadiendo pelis similares a Mushibugyou OVA...
# Añadiendo pelis similares a NHK ni Youkoso!...
# Añadiendo pelis similares a Nabari no Ou...
# Añadiendo pelis similares a Nagi no Asukara...
# Añadiendo pelis similares a Nana to Kaoru...
# Añadiendo pelis similares a Nanatsu no Taizai...
# Añadiendo pelis similares a Nanatsu no Taizai: Seisen no Shirushi...
# Añadiendo pelis similares a Naruto...
# Añadiendo pelis similares a Naruto Movie 1: Dai Katsugeki!! Yuki Hime Shinobu Houjou Dattebayo!...
# Añadiendo pelis similares a Naruto Movie 2: Dai Gekitotsu! Maboroshi no Chiteiiseki Dattebayo!...
# Añadiendo pelis similares a Naruto Movie 3: Dai Koufun! Mikazuki Jima no Animaru Panikku Dattebayo!...
# Añadiendo pelis similares a Naruto: Akaki Yotsuba no Clover wo Sagase...
# Añadiendo pelis similares a Naruto: Dai Katsugeki!! Yuki Hime Shinobu Houjou Dattebayo! Special: Konoha Annual Sports Festival...
# Añadiendo pelis similares a Naruto: Shippuuden Movie 1...
# Añadiendo pelis similares a Naruto: Shippuuden Movie 2 - Kizuna...
# Añadiendo pelis similares a Naruto: Shippuuden Movie 3 - Hi no Ishi wo Tsugu Mono...
# Añadiendo pelis similares a Naruto: Shippuuden Movie 5 - Blood Prison...
# Añadiendo pelis similares a Nazo no Kanojo X...
# Añadiendo pelis similares a Nazo no Kanojo X: Nazo no Natsu Matsuri...
# Añadiendo pelis similares a Neon Genesis Evangelion...
# Añadiendo pelis similares a New Prince of Tennis...
# Añadiendo pelis similares a Nisekoi...
# Añadiendo pelis similares a No Game No Life...
# Añadiendo pelis similares a Nobunaga Concerto...
# Añadiendo pelis similares a Noir...
# Añadiendo pelis similares a Noragami...
# Añadiendo pelis similares a Noragami OVA...
# Añadiendo pelis similares a Nourin...
# Añadiendo pelis similares a Nozo x Kimi...
# Añadiendo pelis similares a Nozoki Ana...
# Añadiendo pelis similares a Nyan Koi!...
# Añadiendo pelis similares a Okusama ga Seitokaichou!...
# Añadiendo pelis similares a Omamori Himari...
# Añadiendo pelis similares a One Outs...
# Añadiendo pelis similares a Oneechan ga Kita...
# Añadiendo pelis similares a OnegaiâTeacher...
# Añadiendo pelis similares a OnegaiâTeacher: Himitsu na Futari...
# Añadiendo pelis similares a OnegaiâTeacher: Reminiscence Disc...
# Añadiendo pelis similares a Oniichan dakedo Ai Sae Areba Kankeinai yo ne!...
# Añadiendo pelis similares a Ookami-san to Shichinin no Nakama-tachi...
# Añadiendo pelis similares a Ookiku Furikabutte...
# Añadiendo pelis similares a Ookiku Furikabutte Special...
# Añadiendo pelis similares a Ookiku Furikabutte: Natsu no Taikai-hen...
# Añadiendo pelis similares a Ore Monogatari!!...
# Añadiendo pelis similares a Ore no Imouto ga Konnani Kawaii Wake ga Nai...
# Añadiendo pelis similares a Ore no Imouto ga Konnani Kawaii Wake ga Nai Specials...
# Añadiendo pelis similares a Ore no Imouto ga Konnani Kawaii Wake ga Nai....
# Añadiendo pelis similares a Ore no Imouto ga Konnani Kawaii Wake ga Nai. Specials...
# Añadiendo pelis similares a Ore no Imouto ga Konnani Kawaii Wake ga Nai: SD Chara ni Yoru Character Commentary...
# Añadiendo pelis similares a Ore no Kanojo to Osananajimi ga Shuraba Sugiru...
# Añadiendo pelis similares a Ore no Nounai Sentakushi ga, Gakuen Love Comedy wo Zenryoku de Jama Shiteiru...
# Añadiendo pelis similares a Ore no Nounai Sentakushi ga, Gakuen Love Comedy wo Zenryoku de Jama Shiteiru OVA...
# Añadiendo pelis similares a Outbreak Company...
# Añadiendo pelis similares a Overlord...
# Añadiendo pelis similares a Papa no Iukoto wo Kikinasai!...
# Añadiendo pelis similares a Papa no Iukoto wo Kikinasai! OVA...
# Añadiendo pelis similares a Papa no Iukoto wo Kikinasai!: Pokkapoka...
# Añadiendo pelis similares a Phi Brain: Kami no Puzzle...
# Añadiendo pelis similares a Piano no Mori...
# Añadiendo pelis similares a Pokemon...
# Añadiendo pelis similares a Pokemon Advanced Generation...
# Añadiendo pelis similares a Pokemon Housoukyoku...
# Añadiendo pelis similares a Pokemon: Maboroshi no Pokemon Lugia Bakutan...
# Añadiendo pelis similares a Pokemon: Mewtwo no Gyakushuu...
# Añadiendo pelis similares a Pokemon: Pikachu no Natsuyasumi...
# Añadiendo pelis similares a Pokemon: Pikachu no Summer Bridge Story...
# Añadiendo pelis similares a Pokemon: Slowking no Ichinichi...
# Añadiendo pelis similares a Pokemon: The Origin...
# Añadiendo pelis similares a Prince of Tennis...
# Añadiendo pelis similares a Princess Lover!...
# Añadiendo pelis similares a Rail Wars!...
# Añadiendo pelis similares a Re:Zero kara Hajimeru Isekai Seikatsu...
# Añadiendo pelis similares a Rescue Me!...
# Añadiendo pelis similares a Robot Girls Z...
# Añadiendo pelis similares a Robot Girls Z Plus...
# Añadiendo pelis similares a Rosario to Vampire...
# Añadiendo pelis similares a Rosario to Vampire Capu2...
# Añadiendo pelis similares a Rurouni Kenshin: Meiji Kenkaku Romantan...
# Añadiendo pelis similares a Ryuugajou Nanana no Maizoukin (TV)...
# Añadiendo pelis similares a Saenai Heroine no Sodatekata...
# Añadiendo pelis similares a Saenai Heroine no Sodatekata: Ai to Seishun no Service Kai...
# Añadiendo pelis similares a Saikin, Imouto no Yousu ga Chotto Okashiinda ga....
# Añadiendo pelis similares a Saint Seiya...
# Añadiendo pelis similares a Saint Seiya: Meiou Hades Elysion-hen...
# Añadiendo pelis similares a Saint Seiya: Meiou Hades Juuni Kyuu-hen...
# Añadiendo pelis similares a Saint Seiya: Meiou Hades Meikai-hen...
# Añadiendo pelis similares a SaintâOniisan...
# Añadiendo pelis similares a SaintâOniisan (Movie)...
# Añadiendo pelis similares a Sakura Trick...
# Añadiendo pelis similares a Sakurasou no Pet na Kanojo...
# Añadiendo pelis similares a Samurai 7...
# Añadiendo pelis similares a Samurai Champloo...
# Añadiendo pelis similares a Samurai Flamenco...
# Añadiendo pelis similares a Sankarea...
# Añadiendo pelis similares a Sankarea OVA...
# Añadiendo pelis similares a Sankarea: Wagahai mo... Zombie de Aru......
# Añadiendo pelis similares a Sayonara Zetsubou Sensei...
# Añadiendo pelis similares a School Rumble...
# Añadiendo pelis similares a School Rumble Ichi Gakki Hoshuu...
# Añadiendo pelis similares a School Rumble Ni Gakki...
# Añadiendo pelis similares a School Rumble San Gakki...
# Añadiendo pelis similares a Seikimatsu Occult Gakuin...
# Añadiendo pelis similares a Seikimatsu Occult Gakuin Specials...
# Añadiendo pelis similares a Seikoku no Dragonar...
# Añadiendo pelis similares a Seitokai Yakuindomo...
# Añadiendo pelis similares a Seitokai Yakuindomo OVA...
# Añadiendo pelis similares a Seitokai Yakuindomo*...
# Añadiendo pelis similares a Sekai Seifuku: Bouryaku no Zvezda...
# Añadiendo pelis similares a Sekirei...
# Añadiendo pelis similares a Sekirei: Hajimete no Otsukai...
# Añadiendo pelis similares a Sekirei: Pure Engagement...
# Añadiendo pelis similares a Sekirei: Pure Engagement - Kanwa ni Dai...
# Añadiendo pelis similares a Sen to Chihiro no Kamikakushi...
# Añadiendo pelis similares a Seto no Hanayome...
# Añadiendo pelis similares a Shigatsu wa Kimi no Uso...
# Añadiendo pelis similares a Shijou Saikyou no Deshi Kenichi...
# Añadiendo pelis similares a Shijou Saikyou no Deshi Kenichi OVA...
# Añadiendo pelis similares a Shimoneta to Iu Gainen ga Sonzai Shinai Taikutsu na Sekai...
# Añadiendo pelis similares a Shinmai Maou no Testament...
# Añadiendo pelis similares a Shinmai Maou no Testament OVA...
# Añadiendo pelis similares a Shonan Junai Gumi!...
# Añadiendo pelis similares a Slam Dunk...
# Añadiendo pelis similares a Slam Dunk (Movie)...
# Añadiendo pelis similares a Slayers...
# Añadiendo pelis similares a Solty Rei...
# Añadiendo pelis similares a Sora no Manimani...
# Añadiendo pelis similares a Sora no Manimani Specials...
# Añadiendo pelis similares a Sora no Otoshimono...
# Añadiendo pelis similares a Sora no Otoshimono: Forte...
# Añadiendo pelis similares a Sora no Otoshimono: Project Pink...
# Añadiendo pelis similares a Soul Eater...
# Añadiendo pelis similares a Soul Eater NOT!...
# Añadiendo pelis similares a SpaceâDandy...
# Añadiendo pelis similares a SpaceâDandy Picture Drama...
# Añadiendo pelis similares a Steins;Gate...
# Añadiendo pelis similares a Steins;Gate Movie: Fuka Ryouiki no DÃ©jÃ  vu...
# Añadiendo pelis similares a Steins;Gate: Oukoubakko no Poriomania...
# Añadiendo pelis similares a Stranger: Mukou Hadan...
# Añadiendo pelis similares a Strike the Blood...
# Añadiendo pelis similares a Summer Wars...
# Añadiendo pelis similares a Suzuka...
# Añadiendo pelis similares a Sword Art Online...
# Añadiendo pelis similares a Tamako Love Story...
# Añadiendo pelis similares a Tamako Market...
# Añadiendo pelis similares a Tari Tari...
# Añadiendo pelis similares a Tasogare Otome x Amnesia...
# Añadiendo pelis similares a Tasogare Otome x Amnesia: Taima Otome...
# Añadiendo pelis similares a Tenjou Tenge...
# Añadiendo pelis similares a Tenjou Tenge: The Past Chapter...
# Añadiendo pelis similares a Tenjou Tenge: The Ultimate Fight...
# Añadiendo pelis similares a Tetsuwan Birdy Decode...
# Añadiendo pelis similares a To LOVE-Ru...
# Añadiendo pelis similares a To LOVE-Ru Darkness...
# Añadiendo pelis similares a To LOVE-Ru Darkness OVA...
# Añadiendo pelis similares a To LOVE-Ru OVA...
# Añadiendo pelis similares a Toaru Majutsu no Index...
# Añadiendo pelis similares a Toki wo Kakeru Shoujo...
# Añadiendo pelis similares a Tokyo Ghoul...
# Añadiendo pelis similares a Tokyo Ghoul âA...
# Añadiendo pelis similares a Tokyo Magnitude 8.0...
# Añadiendo pelis similares a Tokyo Ravens...
# Añadiendo pelis similares a Tonari no Kaibutsu-kun...
# Añadiendo pelis similares a Tonari no Kaibutsu-kun: Tonari no Gokudou-kun...
# Añadiendo pelis similares a Tonari no Seki-kun...
# Añadiendo pelis similares a Tonari no Seki-kun OVA...
# Añadiendo pelis similares a Toradora!...
# Añadiendo pelis similares a Tottoko Hamtarou...
# Añadiendo pelis similares a Trigun...
# Añadiendo pelis similares a Trinity Seven...
# Añadiendo pelis similares a Tsubasa to Hotaru...
# Añadiendo pelis similares a Uchuu Kyoudai...
# Añadiendo pelis similares a Uchuu Kyoudai: Apo&#039;s Dream...
# Añadiendo pelis similares a Usagi Drop...
# Añadiendo pelis similares a Usagi Drop Specials...
# Añadiendo pelis similares a Wake Up, Girls!...
# Añadiendo pelis similares a Wake Up, Girls! Shichinin no Idol...
# Añadiendo pelis similares a Watashi ga Motenai no wa Dou Kangaetemo Omaera ga Warui!...
# Añadiendo pelis similares a Witch Craft Works...
# Añadiendo pelis similares a Wizard Barristers: Benmashi Cecil...
# Añadiendo pelis similares a Working!!...
# Añadiendo pelis similares a Working&#039;!!...
# Añadiendo pelis similares a Yahari Ore no Seishun Love Comedy wa Machigatteiru....
# Añadiendo pelis similares a Yahari Ore no Seishun Love Comedy wa Machigatteiru. OVA...
# Añadiendo pelis similares a Yahari Ore no Seishun Love Comedy wa Machigatteiru. Zoku...
# Añadiendo pelis similares a Yamada-kun to 7-nin no Majo (OVA)...
# Añadiendo pelis similares a Yamada-kun to 7-nin no Majo (TV)...
# Añadiendo pelis similares a Yondemasu yo, Azazel-san....
# Añadiendo pelis similares a Yondemasu yo, Azazel-san. (TV)...
# Añadiendo pelis similares a Yondemasu yo, Azazel-san. Z...
# Añadiendo pelis similares a Yowamushi Pedal...
# Añadiendo pelis similares a Yozakura Quartet...
# Añadiendo pelis similares a Yozakura Quartet: Hana no Uta...
# Añadiendo pelis similares a Yozakura Quartet: Hoshi no Umi...
# Añadiendo pelis similares a Yuusha ni Narenakatta Ore wa Shibushibu Shuushoku wo Ketsui Shimashita....
# Añadiendo pelis similares a Yuusha ni Narenakatta Ore wa Shibushibu Shuushoku wo Ketsui Shimashita. OVA...
# Añadiendo pelis similares a YuuâYuuâHakusho...
# Añadiendo pelis similares a YuâGiâOh!...
# Añadiendo pelis similares a YuâGiâOh! Duel Monsters...
# Añadiendo pelis similares a YuâGiâOh!: Duel Monsters GX...
# Añadiendo pelis similares a Zan Sayonara Zetsubou Sensei...
# Añadiendo pelis similares a Zero no Tsukaima...
# Añadiendo pelis similares a Zero no Tsukaima F...
# Añadiendo pelis similares a Zero no Tsukaima: Futatsuki no Kishi...
# Añadiendo pelis similares a Zero no Tsukaima: Princesses no Rondo...
# Añadiendo pelis similares a Zetsumetsu Kigu Shoujo: Amazing Twins...
# Añadiendo pelis similares a Zoku Sayonara Zetsubou Sensei...
# Añadiendo pelis similares a xxxHOLiC...
# Ordenando...
# Steins;Gate                                                 9.0
# Sen to Chihiro no Kamikakushi                               8.0
# Log Horizon                                                 8.0
# Ano Hi Mita Hana no Namae wo Bokutachi wa Mada Shiranai.    7.0
# Byousoku 5 Centimeter                                       7.0
# Kiseijuu: Sei no Kakuritsu                                  7.0
# Durarara!!                                                  7.0
# Hataraku Maou-sama!                                         7.0
# Magi: The Labyrinth of Magic                                7.0
# Boku wa Tomodachi ga Sukunai                                7.0
# dtype: float64
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:7: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   simCandidates = pd.concat([simCandidates, sims])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])
# C:\Users\Moha\AppData\Local\Temp\ipykernel_13000\3918027672.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[i])

# %%
simCandidates = simCandidates.groupby(simCandidates.index).sum()

simCandidates.sort_values(inplace = True, ascending = False)
simCandidates.head(10)
# Out:
# Sword Art Online       37.106036
# No Game No Life        32.066327
# Shingeki no Kyojin     29.536725
# Angel Beats!           27.892219
# Toradora!              26.839007
# Ao no Exorcist         20.731991
# Death Note             20.585854
# Tokyo Ghoul            20.519703
# Hataraku Maou-sama!    18.675164
# Mirai Nikki (TV)       18.334022
# dtype: float64

# %%
filteredSims = simCandidates.drop(myRatings.index, errors='ignore')
filteredSims.head(10)
# Out:
# Shingeki no Kyojin                    29.536725
# Mirai Nikki (TV)                      18.334022
# Code Geass: Hangyaku no Lelouch        7.013898
# Another                                6.689501
# Elfen Lied                             6.258341
# Guilty Crown                           6.118749
# Clannad                                5.918044
# Bakemonogatari                         5.260219
# Fullmetal Alchemist: Brotherhood       5.241907
# Code Geass: Hangyaku no Lelouch R2     4.557099
# dtype: float64
